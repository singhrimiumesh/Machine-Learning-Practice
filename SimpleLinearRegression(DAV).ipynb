# %%
sale <-read.csv("/tvmarketing.csv")

# %%
sale
# Out:
#   TV Sales
# 1 10  5
# 2 23 15
# 3  6  5
# 4 12  8
# 5 19 11
# 6 21 12
# 7 25 19
# 8 23 11
# 9 29 13

# %%
summary(sale)
# Out:
#        TV            Sales
#  Min.   : 6.00   Min.   : 5
#  1st Qu.:12.00   1st Qu.: 8
#  Median :21.00   Median :11
#  Mean   :18.67   Mean   :11
#  3rd Qu.:23.00   3rd Qu.:13
#  Max.   :29.00   Max.   :19

# %%
head(sale)
# Out:
#   TV Sales
# 1 10  5
# 2 23 15
# 3  6  5
# 4 12  8
# 5 19 11
# 6 21 12

# %%
plot(sale)
# Out:
# plot without title

# %%
library("caTools")

# %%
install.packages("caTools")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library("caTools")

# %%
split <- sample.split(sale, SplitRatio=0.7)

# %%
split
# Out:
# [1]  TRUE FALSE

# %%
train <- subset(sale, split="TRUE")
# Out:
# Warning message:
# “In subset.data.frame(sale, split = "TRUE") :
#  extra argument ‘split’ will be disregarded”

# %%
test <- subset(sale, split="FALSE")
# Out:
# Warning message:
# “In subset.data.frame(sale, split = "FALSE") :
#  extra argument ‘split’ will be disregarded”

# %%
train
# Out:
#   TV Sales
# 1 10  5
# 2 23 15
# 3  6  5
# 4 12  8
# 5 19 11
# 6 21 12
# 7 25 19
# 8 23 11
# 9 29 13

# %%
test
# Out:
#   TV Sales
# 1 10  5
# 2 23 15
# 3  6  5
# 4 12  8
# 5 19 11
# 6 21 12
# 7 25 19
# 8 23 11
# 9 29 13

# %%
model <-lm(Sales~., data=train)

# %%
summary(model)
# Out:
# Call:
# lm(formula = Sales ~ ., data = train)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.2546 -1.5929 -0.1695  0.4411  4.7794
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   1.5078     2.3271   0.648  0.53769
# TV            0.5085     0.1163   4.374  0.00326 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.52 on 7 degrees of freedom
# Multiple R-squared:  0.7321,	Adjusted R-squared:  0.6939
# F-statistic: 19.13 on 1 and 7 DF,  p-value: 0.003258

# %%
pred <-predict(model, test)

# %%
pred
# Out:
#         1         2         3         4         5         6         7         8
#  6.592908 13.203546  4.558865  7.609929 11.169504 12.186525 14.220567 13.203546
#         9
# 16.254610

# %%
plot(sale)
# Out:
# plot without title

# %%
plot(pred, type="l", lty= 1.8, col="blue")
# Out:
# plot without title

# %%
plot(test$Sales, type="l", lty= 1.8, col="red")
# Out:
# plot without title

# %%
plot(pred, type="l" , lty = 1.8, col="blue")
# Out:
# plot without title

# %%
pred
# Out:
#         1         2         3         4         5         6         7         8
#  6.592908 13.203546  4.558865  7.609929 11.169504 12.186525 14.220567 13.203546
#         9
# 16.254610

# %%
rmse <- sqrt(mean((pred - sale$Sales)^2))
rmse
# Out:
# [1] 2.22276
