# %% [markdown]
# <a href="https://colab.research.google.com/github/singhrimiumesh/Machine-Learning-Practice/blob/main/MultiLinearRegression(R_Language).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data <- read.csv("/content/Student_Performance.csv")

# %%
attach(data)

# %%
summary(data)
# Out:
#  Hours.Studied   Previous.Scores Extracurricular.Activities  Sleep.Hours
#  Min.   :1.000   Min.   :40.00   Length:10000               Min.   :4.000
#  1st Qu.:3.000   1st Qu.:54.00   Class :character           1st Qu.:5.000
#  Median :5.000   Median :69.00   Mode  :character           Median :7.000
#  Mean   :4.993   Mean   :69.45                              Mean   :6.531
#  3rd Qu.:7.000   3rd Qu.:85.00                              3rd Qu.:8.000
#  Max.   :9.000   Max.   :99.00                              Max.   :9.000
#  Sample.Question.Papers.Practiced Performance.Index
#  Min.   :0.000                    Min.   : 10.00
#  1st Qu.:2.000                    1st Qu.: 40.00
#  Median :5.000                    Median : 55.00
#  Mean   :4.583                    Mean   : 55.22
#  3rd Qu.:7.000                    3rd Qu.: 71.00
#  Max.   :9.000                    Max.   :100.00

# %%
names(data)
# Out:
# [1] "Hours.Studied"                    "Previous.Scores"
# [3] "Extracurricular.Activities"       "Sleep.Hours"
# [5] "Sample.Question.Papers.Practiced" "Performance.Index"

# %%
class(Hours.Studied)
# Out:
# [1] "integer"

# %%
class(Extracurricular.Activities)
# Out:
# [1] "character"

# %%
levels(Extracurricular.Activities)
# Out:
# NULL

# %%
levels(Hours.Studied)
# Out:
# NULL

# %%
model <-lm(Hours.Studied~ Previous.Scores + Sleep.Hours )

# %%
summary(model)
# Out:
# Call:
# lm(formula = Hours.Studied ~ Previous.Scores + Sleep.Hours)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.0524 -2.0204  0.0082  2.0328  4.0669
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)      5.108291   0.145752  35.048   <2e-16 ***
# Previous.Scores -0.001851   0.001493  -1.240    0.215
# Sleep.Hours      0.002014   0.015270   0.132    0.895
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.589 on 9997 degrees of freedom
# Multiple R-squared:  0.0001552,	Adjusted R-squared:  -4.478e-05
# F-statistic: 0.7761 on 2 and 9997 DF,  p-value: 0.4602

# %%
cor(Previous.Scores , Sleep.Hours, method="pearson")
# Out:
# [1] 0.005944219

# %%
cor(Previous.Scores , Sleep.Hours, method="spearman")
# Out:
# [1] 0.005981067

# %%
confint(model, conf.level = 0.90)
# Out:
#                 2.5 %        97.5 %
# (Intercept)      4.822588189 5.393993500
# Previous.Scores -0.004777785 0.001075849
# Sleep.Hours     -0.027918066 0.031945540

# %%
plot(model)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
